# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
dataset = pd.read_csv(r"C:\Users\88001381\Desktop\PV_Model_Data(4).csv")

# %%
dataset1 = pd.read_csv(r"C:\Users\88001381\Desktop\PV_Model_Data(3).csv")

# %%
dataset
# Out:
#         COLLECTION_TILL_DATE  TENURE  ODBKT  MOB  SOHPOD_PREASSIGN  PAID_PER  \
# 0                   474180.0      36      0   21         317226.73  0.546819
# 1                    52920.0      84      0    6         485118.42  0.047154
# 2                    14020.0      12      0   10         120077.18  0.000764
# 3                  1310624.0      23      0   16         555053.57  0.675001
# 4                    77000.0      59      0    7         448698.05  0.089882
# ...                      ...     ...    ...  ...               ...       ...
# 135015              158889.0      83      0   17         452584.23  0.146129
# 135016              398310.0      60      0   32         292172.59  0.949143
# 135017                2661.0      12      0    3          75947.81  0.000568
# 135018                 914.0      12      0    2          39182.13 -0.000386
# 135019               73108.0      60      0    7         453248.00  0.093738
#
# ...

# %%
X_train = dataset.iloc[:, :-1]  
y_train = dataset1.iloc[:, -1]

# %%
rf_classifier = RandomForestClassifier(n_estimators=5, criterion = 'entropy', random_state=10, max_depth = 25)

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=25, n_estimators=5,
#                        random_state=10)

# %%
y_pred = rf_classifier.predict(X_train)

# %%
conf_matrix = confusion_matrix(y_train, y_pred)
print(conf_matrix)
# Out:
# [[121911    551]
#  [  2141  10417]]

# %%
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

# %%
print('Accuracy:', accuracy_score(y_train, y_pred))
print('F1 score:', f1_score(y_train, y_pred))
print('Recall:', recall_score(y_train, y_pred))
print('Precision:', precision_score(y_train, y_pred))
# Out:
# Accuracy: 0.9800622130054807
# F1 score: 0.885573408144181
# Recall: 0.8295110686415035
# Precision: 0.949762946754194

# %%
import seaborn as sns

# %%
dataset
# Out:
#          Month  FIN_AMOUNT  IRR_CUSTOMER  ASSET_COST       LTV  \
# 0       202112    700000.0         9.981    932886.0  0.750360
# 1       202203    509126.0        11.359    676423.0  0.708274
# 2       202207    120169.0        13.968    135227.0  0.888646
# 3       202112   1707863.0         9.889   1707863.0  1.000000
# 4       202202    493011.0        11.525    646244.0  0.752804
# ...        ...         ...           ...         ...       ...
# 135015  202204    530038.0        11.552    686837.0  0.755773
# 135016  202205    574497.0        10.047    688765.0  0.820309
# 135017  202112     75991.0        13.978    113800.0  0.667759
# 135018  202111     39167.0        13.960     96329.0  0.406596
# 135019  202109    500129.0         9.220    717742.0  0.689663
#
#         COLLECTION_TILL_DATE        SOHP  TENURE  ODAMT  COLLECTION_MONTH  \
# 0                   474180.0  317226.730      36    0.0           22580.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135020 entries, 0 to 135019
# Data columns (total 69 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Month                 135020 non-null  int64
#  1   FIN_AMOUNT            135020 non-null  float64
#  2   IRR_CUSTOMER          135020 non-null  float64
#  3   ASSET_COST            135020 non-null  float64
#  4   LTV                   135020 non-null  float64
#  5   COLLECTION_TILL_DATE  135020 non-null  float64
#  6   SOHP                  135020 non-null  float64
#  7   TENURE                135020 non-null  int64
#  8   ODAMT                 135020 non-null  float64
#  9   COLLECTION_MONTH      135020 non-null  float64
#  10  FIRST_EMI             135020 non-null  int64
#  11  EMI                   135020 non-null  float64
#  12  ODBKT                 135020 non-null  int64
#  13  INCEPTION_MONTH       135020 non-null  int64
# ...

# %%
dataset.Column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1876\694115427.py in <module>
# ----> 1 dataset.Column
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Column'

# %%
print(dataset)
# Out:
#          Month  FIN_AMOUNT  IRR_CUSTOMER  ASSET_COST       LTV  \
# 0       202112    700000.0         9.981    932886.0  0.750360
# 1       202203    509126.0        11.359    676423.0  0.708274
# 2       202207    120169.0        13.968    135227.0  0.888646
# 3       202112   1707863.0         9.889   1707863.0  1.000000
# 4       202202    493011.0        11.525    646244.0  0.752804
# ...        ...         ...           ...         ...       ...
# 135015  202204    530038.0        11.552    686837.0  0.755773
# 135016  202205    574497.0        10.047    688765.0  0.820309
# 135017  202112     75991.0        13.978    113800.0  0.667759
# 135018  202111     39167.0        13.960     96329.0  0.406596
# 135019  202109    500129.0         9.220    717742.0  0.689663
#
#         COLLECTION_TILL_DATE        SOHP  TENURE  ODAMT  COLLECTION_MONTH  \
# 0                   474180.0  317226.730      36    0.0           22580.0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(dataset.isnull().sum())
# Out:
# COLLECTION_TILL_DATE    0
# TENURE                  0
# ODBKT                   0
# MOB                     0
# SOHPOD_PREASSIGN        0
# PAID_PER                0
# TENURE_LEFT             0
# MaxBkt_24M              0
# MinBkt_24M              0
# Mode_Bkt_24M            0
# SDBkt_24M               0
# Bounce_1M               0
# Del_in_Last_12M         0
# ASSET_LTV               0
# ME1                     0
# CE1                     0
# IRR_CUSTOMER_D          0
# APPLICATION_USAGE_B     0
# BRANCH_NEW_B            0
# ASSET_CATEGORY2_B       0
# NORM_B                  0
# CUSTOMER_SEGMENT_B      0
# COMPANY_INDIVIDUAL_B    0
# SOURCING_B              0
# SCHEME_FINPROD_B        0
# TRACK_RECORD_B          0
# REGION_NEW_B            0
# dtype: int64

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    122462
#            1       0.95      0.83      0.89     12558
#
#     accuracy                           0.98    135020
#    macro avg       0.97      0.91      0.94    135020
# weighted avg       0.98      0.98      0.98    135020
